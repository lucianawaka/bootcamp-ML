# %%
# Bibliotecas
import pandas as pd
import numpy as np

# Bibliotecas gráficas
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

# Identificar valores nulos
#!pip install missingno
import missingno as msno

# Avisos
import warnings
warnings.filterwarnings('ignore')

# Configurações
# Pandas
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)

# Matplotlib
plt.rcParams['figure.figsize'] = (12, 6)
plt.style.use('ggplot')

# %%
base = pd.read_csv('water_potability.csv')

# %%
base.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
# Últimos
base.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
# Campos nulos
base.isnull().sum() /len(base) * 100
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %%
# Nulos em forma gráfica
msno.matrix( base, color=(0, 0.5, 0.5), figsize=(12, 5) )
# Out:
# <AxesSubplot:>

# %%
# Describe
base.describe().transpose()
# Out:
#                   count          mean          std         min           25%  \
# ph               2785.0      7.080795     1.594320    0.000000      6.093092
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690297
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          2495.0    333.775777    41.416840  129.000000    307.699498
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3114.0     66.396293    16.175008    0.738000     55.844536
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.036752      8.062066     14.000000
# Hardness           196.967627    216.667456    323.124000
# Solids           20927.833607  27332.762127  61227.196008
# Chloramines          7.130299      8.114887     13.127000
# Sulfate            333.073546    359.950170    481.030642
# Conductivity       421.884968    481.792304    753.342620
# Organic_carbon      14.218338     16.557652     28.300000
# Trihalomethanes     66.622485     77.337473    124.000000
# Turbidity            3.955028      4.500320      6.739000
# Potability           0.000000      1.000000      1.000000

# %%
copia_base = base.copy
# Removendo nulos
base.dropna( inplace=True )

# Dimensão
base.shape
# Out:
# (2011, 10)

# %%
# Variável Target
base['Potability'].value_counts( normalize=True) * 100
# Out:
# 0    59.671805
# 1    40.328195
# Name: Potability, dtype: float64

# %%
# Plot
plt.title('Distribuição da Target')

sns.countplot(
    data = base,
    x = 'Potability',
    palette='husl'
)
# Out:
# <AxesSubplot:title={'center':'Distribuição da Target'}, xlabel='Potability', ylabel='count'>

# %%
# Plot target x categorias
Figura, Eixo = plt.subplots( figsize=(18,14) )
# Título
plt.suptitle('Análise da Target x Características', fontsize=22, color='#404040')

# Grid
colunas = 2
linhas = int(len(base.columns) / 2)

# Loop dos Plots

for Posicao, Coluna in enumerate( base.columns ):
    if Posicao == 9:
        pass
    else:
        plt.subplot( linhas, colunas, Posicao + 1 )
        plt.title(f'Target x {Coluna}', loc='left', fontsize=12)
        sns.boxplot(
            data=base,
            x='Potability',
            y=Coluna,
            width=0.25,  
        )
        
        plt.xlabel('')
# Ajustando os espaços
plt.subplots_adjust(
    left=0.1,
    bottom=0.1,
    right=0.9,
    top=0.92,
    wspace=0.20,
    hspace=0.30
);

# %%
# Correlação

# Tamanho
plt.figure( figsize=(12, 7) )

# Ajustar a matriz
correlacao = base.corr()
matriz = np.triu( correlacao )

sns.heatmap( base.corr(), mask=matriz, annot=True, cmap='coolwarm_r' );

# %%
# Divisão dos dados
Caracteristicas = base.drop( columns=['Potability'] )
Previsor = base['Potability']

# %%
# YellowBrick
from yellowbrick.features import ParallelCoordinates

# Divisão
Features = Caracteristicas
Classe   = [0, 1]

Visualizador = ParallelCoordinates(
    classes = Classe,
    features = Features,
    sample=0.5,
    shuffle=True
)

Visualizador.fit_transform( Features, Previsor )
Visualizador.show()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickValueError                     Traceback (most recent call last)
# Input In [55], in <cell line: 15>()
#       6 Classe   = [0, 1]
#       8 Visualizador = ParallelCoordinates(
#       9     classes = Classe,
#      10     features = Features,
#      11     sample=0.5,
#      12     shuffle=True
#      13 )
# ---> 15 Visualizador.fit_transform( Features, Previsor )
#
# File D:\anaconda3\lib\site-packages\sklearn\base.py:855, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
# --> 855     return self.fit(X, y, **fit_params).transform(X)
#
# File D:\anaconda3\lib\site-packages\yellowbrick\features\pcoords.py:390, in ParallelCoordinates.fit(self, X, y, **kwargs)
#     368 """
#     369 The fit method is the primary drawing input for the
#     370 visualization since it has both the X and y data required for the
#    (...)
#     387     Returns the instance of the transformer/visualizer
#     388 """
#     389 # Determine the features, classes, and colors
# --> 390 super(ParallelCoordinates, self).fit(X, y)
#     392 # Convert from pandas data types
#     393 if is_dataframe(X):
#
# File D:\anaconda3\lib\site-packages\yellowbrick\features\base.py:362, in DataVisualizer.fit(self, X, y)
#     343 """
#     344 Fits the visualizer to the training data set by determining the
#     345 target type, colors, classes, and range of the data to ensure that
#    (...)
#     359     Returns the instance of the transformer/visualizer
#     360 """
#     361 # Compute the features from the data
# --> 362 super(DataVisualizer, self).fit(X, y)
#     364 # Determine the target color type
#     365 self._determine_target_color_type(y)
#
# File D:\anaconda3\lib\site-packages\yellowbrick\features\base.py:193, in MultiFeatureVisualizer.fit(self, X, y)
#     189 if self.features is not None:
#     190     # Use the user-specified features with some checking
#     191     # TODO: allow the user specified features to filter the dataset
#     192     if len(self.features) != n_columns:
# --> 193         raise YellowbrickValueError(
#     194             (
#     195                 "number of supplied feature names does not match the number "
#     196                 "of columns in the training data."
#     197             )
#     198         )
#     200     self.features_ = np.array(self.features)
#     202 else:
#     203     # Attempt to determine the feature names from the input data
#
# YellowbrickValueError: number of supplied feature names does not match the number of columns in the training data.
